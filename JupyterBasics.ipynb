# %%
import sys
sys.version
# Out:
# '3.5.1 |Anaconda 2.5.0 (x86_64)| (default, Dec  7 2015, 11:24:55) \n[GCC 4.2.1 (Apple Inc. build 5577)]'

# %%
response = requests.get('http://localhost:8182/graphs/bio4j/vertices/255744', auth=('re', 're'))
data = response.json()

for key, value in data.items():
    print(key, value, "\n\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-777b8dfecd2a> in <module>()
# ----> 1 response = requests.get('http://localhost:8182/graphs/bio4j/vertices/255744', auth=('re', 're'))
#       2 data = response.json()
#       3
#       4 for key, value in data.items():
#       5     print(key, value, "\n\n")
#
# NameError: name 'requests' is not defined

# %%
import sys
sys.executable

# %%
help('modules')

# %%
import sys
for module in sorted(sys.modules.keys()):
    print(module)
# Out:
# Crypto
# Crypto.Cipher
# Crypto.Cipher.AES
# Crypto.Cipher._AES
# Crypto.Cipher.blockalgo
# Crypto.Hash
# Crypto.Hash.SHA256
# Crypto.Hash.hashalgo
# Crypto.Protocol
# Crypto.PublicKey
# Crypto.Random
# Crypto.Random.Fortuna
# Crypto.Random.Fortuna.FortunaAccumulator
# Crypto.Random.Fortuna.FortunaGenerator
# Crypto.Random.Fortuna.SHAd256
# Crypto.Random.OSRNG
# Crypto.Random.OSRNG.posix
# Crypto.Random.OSRNG.rng_base
# Crypto.Random._UserFriendlyRNG
# Crypto.SelfTest
# Crypto.SelfTest.Cipher
# Crypto.SelfTest.Hash
# Crypto.SelfTest.Protocol
# Crypto.SelfTest.PublicKey
# Crypto.SelfTest.Random
# Crypto.SelfTest.Random.Fortuna
# Crypto.SelfTest.Random.OSRNG
# Crypto.SelfTest.Signature
# Crypto.SelfTest.Util
# Crypto.Signature
# Crypto.Util
# Crypto.Util.Counter
# Crypto.Util._counter
# Crypto.Util._number_new
# Crypto.Util.number
# Crypto.Util.py3compat
# Crypto.pct_warnings
# Cython
# Cython.Build
# Cython.Build.Dependencies
# Cython.Build.Tests
# Cython.Compiler
# ...

# %%
import pip
sorted(["%s==%s" % (i.key, i.version) for i in pip.get_installed_distributions()])
# Out:
# ['abstract-rendering==0.5.1',
#  'alabaster==0.7.7',
#  'anaconda-client==1.2.2',
#  'appnope==0.1.0',
#  'appscript==1.0.1',
#  'argcomplete==1.0.0',
#  'astropy==1.1.1',
#  'babel==2.2.0',
#  'beautifulsoup4==4.4.1',
#  'bitarray==0.8.1',
#  'blaze==0.9.0',
#  'bokeh==0.11.0',
#  'boto==2.39.0',
#  'bottlechest==0.7.1',
#  'bottleneck==1.0.0',
#  'cffi==1.2.1',
#  'chardet==2.3.0',
#  'clyent==1.2.0',
#  'colorama==0.3.6',
#  'conda-build==1.18.2',
#  'conda-env==2.4.5',
#  'conda==3.19.1',
#  'configobj==5.0.6',
#  'cryptography==1.0.2',
#  'cycler==0.9.0',
#  'cython==0.23.4',
#  'cytoolz==0.7.5',
#  'datashape==0.5.0',
#  'decorator==4.0.6',
#  'docutils==0.12',
#  'dynd==f641248',
#  'et-xmlfile==1.0.1',
#  'fastcache==1.0.2',
#  'flask==0.10.1',
#  'futures==3.0.3',
#  'glueviz==0.6.0',
#  'greenlet==0.4.9',
#  'h5py==2.5.0',
#  'idna==2.0',
#  'ipykernel==4.2.2',
#  'ipython-genutils==0.1.0',
#  'ipython==4.0.3',
#  'ipywidgets==4.1.1',
#  'itsdangerous==0.24',
# ...

# %%
import os
os.getcwd()
# Out:
# '/Users/Phoenix/Dropbox/Projects/DNASeqNoteBook'

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_1',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i2',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  '_sh',
#  'exit',
#  'get_ipython',
#  'os',
#  'quit']

# %% [markdown]
# when a module named spam is imported, the interpreter first searches for a built-in module with that name. If not found, it then searches for a file named spam.py in a list of directories given by the variable sys.path. sys.path is initialized from these locations:
#
# the directory containing the input script (or the current directory).
# PYTHONPATH (a list of directory names, with the same syntax as the shell variable PATH).
# the installation-dependent default.

# %%
import sys
sys.path
#print("\n".join(sys.path))
# Out:
# ['',
#  '/Users/Phoenix/anaconda/lib/python35.zip',
#  '/Users/Phoenix/anaconda/lib/python3.5',
#  '/Users/Phoenix/anaconda/lib/python3.5/plat-darwin',
#  '/Users/Phoenix/anaconda/lib/python3.5/lib-dynload',
#  '/Users/Phoenix/anaconda/lib/python3.5/site-packages/Sphinx-1.3.5-py3.5.egg',
#  '/Users/Phoenix/anaconda/lib/python3.5/site-packages/setuptools-19.6.2-py3.5.egg',
#  '/Users/Phoenix/anaconda/lib/python3.5/site-packages',
#  '/Users/Phoenix/anaconda/lib/python3.5/site-packages/aeosa',
#  '/Users/Phoenix/anaconda/lib/python3.5/site-packages/IPython/extensions',
#  '/Users/Phoenix/.ipython']

# %%
a = 3
a
# Out:
# 3

# %%
Ω = 4

# %%
Ω
# Out:
# 4

# %% [markdown]
# # Markdown
# ## Heading
# ### Heading
# #### Heading
# ##### Heading
#
# **Bold Font**
#
# _ Italic Font _
#
# --Scratched text--
#
# <u>Hello world</u>
#
# - item 1
# - item 2
#  - subitem2 1
#  - suitem 2 2
#
# links: [Github](www.github.com)
#
# Horizental line
#
# ...
#
# Imgae:
# ![here](http://ccs.miami.edu/wp-content/uploads/2015/02/ccbi.jpg "Bioinformatics")
#
#
# # Code:
# ```python
# x = 3
# print(x * x)
# ```
#
# # Qutes:
# > heloo world !

# %%
import requests

response = requests.get('http://localhost:8182/graphs/bio4j/', auth=('re', 're'))
data = response.json()

for key, value in data.items():
    print(key, value)
# Out:
# version 2.5.0
# message Invalid username or password.

# %% [markdown]
# ** quering the verticx id **
#
#     /graphs/<graph>/vertices/<id>

# %% [markdown]
#     /graphs/<graph>/vertices?key=<key>&value=<value>

# %%
response = requests.get('http://localhost:8182/graphs/bio4j/vertices?key='com.bio4j.model.go.GoGraph.GoTermType.name'&value={}'.format(pattern), auth=('re', 're'))
data = response.json()

for key, value in data.items():
    print(key, value, "\n\n")

# %%
import rexpro
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-7ee6055f0b28> in <module>()
# ----> 1 import rexpro
#
# ImportError: No module named 'rexpro'
